# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# This markdown cell should also remain. **Look at the plot** of this function:
#
# $$\Large
# f(x) = cos(2x) + e^x$$
#
# <!-- END QUESTION -->

# %% [markdown]
# <!-- BEGIN QUESTION q1 -->
#
# Let's test a multi-cell question.

# %% [markdown]
# This is the second cell.

# %% [markdown]
# This is the third cell.
#
# <!-- END QUESTION -->

# %% [markdown]
# <!-- BEGIN QUESTION q2 -->
#
# Let's ensure that this **code cell is included.**

# %%
plt.plot(x,y**4)

# %% [markdown]
# <!-- END QUESTION -->
